# %%
#import the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load the dataset
df=pd.read_csv(r"C:\Users\Megha\Desktop\School Completion Rates.csv")

# %%
#display the top 5 rows of dataset
df.head()
# Out:
#   ISO_Code      Country Region Sub-region Least developed countries (LDC)  \
# 0      AFG  Afghanistan     SA        NaN                             LDC
# 1      ALB      Albania    ECA       EECA                             NaN
# 2      DZA      Algeria   MENA        NaN                             NaN
# 3      AND      Andorra    ECA         WE                             NaN
# 4      AGO       Angola    SSA        ESA                             LDC
#
#   Africa sub-regions Africa region  Total  Male  Female  ...  Middle  Fourth  \
# 0                NaN           NaN   54.0  67.0    40.0  ...    43.0    60.0
# 1                NaN           NaN   92.0  91.0    93.0  ...    94.0    92.0
# 2    Northern Africa           All   94.0  93.0    94.0  ...    94.0    96.0
# 3                NaN           NaN    NaN   NaN     NaN  ...     NaN     NaN
# 4    Southern Africa           All   51.0  53.0    49.0  ...    44.0    68.0
#
# ...

# %%
#display the rows and column numbers of the dataset in tuple format
df.shape
# Out:
# (202, 25)

# %%
#remove the features with no feature name
df.drop(labels=["Unnamed: 18","Unnamed: 19","Unnamed: 20","Unnamed: 21","Unnamed: 22","Unnamed: 23"],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['ISO_Code', 'Country', 'Region', 'Sub-region',
#        'Least developed countries (LDC)', 'Africa sub-regions',
#        'Africa region', 'Total', 'Male', 'Female', 'Urban', 'Rural', 'Poorest',
#        'Second', 'Middle', 'Fourth', 'Richest', 'Source',
#        ' Total Population, one year before primary '],
#       dtype='object')

# %%
#display the basic information & overview of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202 entries, 0 to 201
# Data columns (total 19 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   ISO_Code                                     202 non-null    object
#  1   Country                                      202 non-null    object
#  2   Region                                       183 non-null    object
#  3   Sub-region                                   96 non-null     object
#  4   Least developed countries (LDC)              40 non-null     object
#  5   Africa sub-regions                           54 non-null     object
#  6   Africa region                                54 non-null     object
#  7   Total                                        99 non-null     float64
#  8   Male                                         99 non-null     float64
# ...

# %%
#find how many null values are present
df.isna().sum()
# Out:
# ISO_Code                                         0
# Country                                          0
# Region                                          19
# Sub-region                                     106
# Least developed countries (LDC)                162
# Africa sub-regions                             148
# Africa region                                  148
# Total                                          103
# Male                                           103
# Female                                         103
# Urban                                          105
# Rural                                          105
# Poorest                                        106
# Second                                         107
# Middle                                         107
# Fourth                                         107
# Richest                                        107
# Source                                         103
# ...

# %%
#remove the features with too many null values
df.drop(labels=["Least developed countries (LDC)","Africa sub-regions","Africa region","Sub-region","Source"]
        ,axis=1,inplace=True)

# %%
df["Total"].fillna(df["Total"].mean(),inplace=True)
df["Male"].fillna(df["Male"].mean(),inplace=True)
df["Female"].fillna(df["Female"].mean(),inplace=True)
df["Urban"].fillna(df["Urban"].mean(),inplace=True)
df["Rural"].fillna(df["Rural"].mean(),inplace=True)
df["Poorest"].fillna(df["Poorest"].mean(),inplace=True)
df["Second"].fillna(df["Second"].mean(),inplace=True)
df["Middle"].fillna(df["Middle"].mean(),inplace=True)
df["Fourth"].fillna(df["Fourth"].mean(),inplace=True)
df["Richest"].fillna(df["Richest"].mean(),inplace=True)

# %%
df.isna().sum()
# Out:
# ISO_Code     0
# Country      0
# Region      19
# Total        0
# Male         0
# Female       0
# Urban        0
# Rural        0
# Poorest      0
# Second       0
# Middle       0
# Fourth       0
# Richest      0
# dtype: int64

# %%
df["Region"].unique()
# Out:
# array(['SA', 'ECA', 'MENA', 'SSA', 'LAC', 'EAP', nan], dtype=object)

# %%
sns.countplot(x=df["Region"],data=df,color="magenta")
# Out:
# <AxesSubplot:xlabel='Region', ylabel='count'>

# %%
df["Region"].fillna("ECA",inplace=True)

# %%
df.isna().sum()
# Out:
# ISO_Code    0
# Country     0
# Region      0
# Total       0
# Male        0
# Female      0
# Urban       0
# Rural       0
# Poorest     0
# Second      0
# Middle      0
# Fourth      0
# Richest     0
# dtype: int64

# %%
df.head()
# Out:
#   ISO_Code      Country Region     Total       Male     Female      Urban  \
# 0      AFG  Afghanistan     SA  54.00000  67.000000  40.000000  71.000000
# 1      ALB      Albania    ECA  92.00000  91.000000  93.000000  94.000000
# 2      DZA      Algeria   MENA  94.00000  93.000000  94.000000  95.000000
# 3      AND      Andorra    ECA  77.20202  76.919192  77.525253  85.371134
# 4      AGO       Angola    SSA  51.00000  53.000000  49.000000  64.000000
#
#        Rural    Poorest     Second     Middle     Fourth    Richest
# 0  48.000000  45.000000  46.000000  43.000000  60.000000  75.000000
# 1  89.000000  87.000000  91.000000  94.000000  92.000000  98.000000
# 2  91.000000  86.000000  95.000000  94.000000  96.000000  99.000000
# 3  70.649485  61.145833  69.578947  75.894737  82.484211  89.663158
# 4  21.000000  15.000000  23.000000  44.000000  68.000000  82.000000

# %%
plt.figure(figsize=(8,8))

plt.subplot(2,2,1)
sns.histplot(x=df["Total"],color="red")

plt.subplot(2,2,2)
sns.histplot(x=df["Male"],color="blue")

plt.subplot(2,2,3)
sns.histplot(x=df["Female"],color="yellow")

plt.subplot(2,2,4)
sns.histplot(x=df["Middle"],color="green")
# Out:
# <AxesSubplot:xlabel='Middle', ylabel='Count'>

# %%
plt.figure(figsize=(10,10))

plt.subplot(2,2,1)
sns.scatterplot(x="Urban",y="Rural",data=df,hue="Region",marker="*")
sns.rugplot(x="Urban",y="Rural",data=df,hue="Region",height=0.1)

plt.subplot(2,2,2)
sns.scatterplot(x="Poorest",y="Second",data=df,hue="Region",marker="*")
sns.rugplot(x="Poorest",y="Second",data=df,hue="Region",height=0.1)

plt.subplot(2,2,3)
sns.scatterplot(x="Middle",y="Fourth",data=df,hue="Region",marker="*")
sns.rugplot(x="Middle",y="Fourth",data=df,hue="Region",height=0.1)

plt.subplot(2,2,4)
sns.scatterplot(x="Total",y="Richest",data=df,hue="Region",marker="*")
sns.rugplot(x="Total",y="Richest",data=df,hue="Region",height=0.1)
# Out:
# <AxesSubplot:xlabel='Total', ylabel='Richest'>

# %%
list_labels=df["Region"].unique()
list_labels
# Out:
# array(['SA', 'ECA', 'MENA', 'SSA', 'LAC', 'EAP', nan], dtype=object)

# %%
val1=len(df[df["Region"]=="SA"])
val2=len(df[df["Region"]=="ECA"])
val3=len(df[df["Region"]=="MENA"])
val4=len(df[df["Region"]=="SSA"])
val5=len(df[df["Region"]=="LAC"])
val6=len(df[df["Region"]=="EAP"])

# %%
list_num=[val1,val2,val3,val4,val5,val6]

# %%
plt.pie(list_num,labels=list_labels,shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x2b8cb4871c0>,
# ...
#  [Text(1.09348781371553, 0.11951736800829614, 'SA'),
#   Text(0.2542939049707023, 1.0702030694661417, 'ECA'),
#   Text(-0.9973398997926702, 0.46401845252268437, 'MENA'),
#   Text(-0.9746124612555986, -0.5100299504590925, 'SSA'),
#   Text(0.15346695487844048, -1.0892418894627303, 'LAC'),
#   Text(0.9973399106538057, -0.46401842917825903, 'EAP')])

# %%
sns.jointplot(x="Urban",y="Rural",data=df,kind="hex",color="olive")

sns.jointplot(x="Male",y="Female",data=df,kind="kde",color="blue")
