# %% [markdown]
# Importing Neccessary Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Loading The Dataset

# %%
#default value is "UFT-8" but sometimes it gives error so we need "latin1" encoding
df=pd.read_csv("Terrorism Data.csv",encoding="latin1")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (4,31,33,61,62,63,76,79,90,92,94,96,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# Showing The Top 5 Rows

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday  ... INT_IDEO  INT_MISC INT_ANY  related
# 0  197000000001   1970       7     2  ...      0.0       0.0     0.0      NaN
# 1  197000000002   1970       0     0  ...      1.0       1.0     1.0      NaN
# 2  197001000001   1970       1     0  ...     -9.0       1.0     1.0      NaN
# 3  197001000002   1970       1     0  ...     -9.0       1.0     1.0      NaN
# 4  197001000003   1970       1     0  ...     -9.0       1.0     1.0      NaN
#
# [5 rows x 135 columns]

# %% [markdown]
# Showing All Column Names

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %% [markdown]
# Showing The Dimensions Of Dataframe In Tuple Format

# %%
df.shape
# Out:
# (73878, 135)

# %% [markdown]
# Checking For Null Values

# %%
df.isna().sum()
# Out:
# eventid           0
# iyear             0
# imonth            0
# iday              0
# approxdate    73744
#               ...
# INT_LOG           1
# INT_IDEO          1
# INT_MISC          1
# INT_ANY           1
# related       65660
# Length: 135, dtype: int64

# %% [markdown]
# Removing Some Null Values

# %%
df=df.drop(labels=["approxdate","related"],axis=1)

# %% [markdown]
# Showing Statistical Analysis

# %%
df.describe()
# Out:
#             eventid         iyear  ...      INT_MISC       INT_ANY
# count  7.387800e+04  73878.000000  ...  73878.000000  73878.000000
# mean   1.988047e+11   1987.981118  ...      0.125722     -2.978126
# std    7.207811e+08      7.207305  ...      0.792256      4.521431
# min    1.970000e+11   1970.000000  ...     -9.000000     -9.000000
# 25%    1.983041e+11   1983.000000  ...      0.000000     -9.000000
# 50%    1.989012e+11   1989.000000  ...      0.000000      0.000000
# 75%    1.994030e+11   1994.000000  ...      0.000000      1.000000
# max    2.002032e+11   2002.000000  ...      1.000000      1.000000
#
# [8 rows x 74 columns]

# %% [markdown]
# Showing Total Information of Dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73878 entries, 0 to 73877
# Columns: 126 entries, eventid to INT_ANY
# dtypes: float64(54), int64(20), object(52)
# memory usage: 71.0+ MB

# %% [markdown]
# Analysing Count Of Terrorist Attacks Per Year

# %%
fig=plt.figure(figsize=(15,6))
sns.countplot(x="iyear",data=df,color="maroon")
plt.title("Count Of Terrorist Attacks Per Year")
# Out:
# Text(0.5, 1.0, 'Count Of Terrorist Attacks Per Year')

# %% [markdown]
# Analysing Count Of Terrorist Attacks Per Month

# %%
fig=plt.figure(figsize=(15,6))
sns.countplot(x="imonth",data=df,color="blue")
plt.title("Count Of Terrorist Attacks Per Month")
# Out:
# Text(0.5, 1.0, 'Count Of Terrorist Attacks Per Month')

# %% [markdown]
# Analysing Count Of Terrorist Attacks Per Day

# %%
fig=plt.figure(figsize=(15,6))
sns.countplot(x="iday",data=df,color="magenta")
plt.title("Count Of Terrorist Attacks Per Day")
# Out:
# Text(0.5, 1.0, 'Count Of Terrorist Attacks Per Day')

# %% [markdown]
# Analysing All Active Terrorist Attacks On Countries

# %%
df["country_txt"].value_counts()
# Out:
# Colombia               6173
# Peru                   6023
# El Salvador            5320
# United Kingdom         4166
# India                  3019
#                        ...
# Andorra                   1
# Antigua and Barbuda       1
# South Vietnam             1
# New Hebrides              1
# Equatorial Guinea         1
# Name: country_txt, Length: 196, dtype: int64

# %%
fig=plt.figure(figsize=(13,6))
sns.distplot(x=df["country"],color="red")
plt.title("Active Terrorist Attacks On Different Countries")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Active Terrorist Attacks On Different Countries')

# %% [markdown]
# Analysing All Active Terrorist Attack Types

# %%
df["attacktype1_txt"].value_counts()
# Out:
# Bombing/Explosion                      29201
# Armed Assault                          16178
# Assassination                          12347
# Facility/Infrastructure Attack          4647
# Hostage Taking (Kidnapping)             3110
# Unknown                                 2663
# Hostage Taking (Barricade Incident)      628
# Unarmed Assault                          385
# Hijacking                                343
# Name: attacktype1_txt, dtype: int64

# %%
fig=plt.figure(figsize=(13,6))
sns.distplot(x=df["attacktype1"],color="darkorange")
plt.title("Active Terrorist Attacks Of Different Types")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Active Terrorist Attacks Of Different Types')

# %% [markdown]
# Analysing The Region vs Country Terrorist Attack

# %%
fig=plt.figure(figsize=(15,7))
sns.scatterplot(x="region",y="country",data=df,color="green",marker="*")
sns.rugplot(x="region",y="country",data=df,color="cyan",height=0.1)

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday  ...  INT_LOG INT_IDEO  INT_MISC INT_ANY
# 0  197000000001   1970       7     2  ...      0.0      0.0       0.0     0.0
# 1  197000000002   1970       0     0  ...      0.0      1.0       1.0     1.0
# 2  197001000001   1970       1     0  ...     -9.0     -9.0       1.0     1.0
# 3  197001000002   1970       1     0  ...     -9.0     -9.0       1.0     1.0
# 4  197001000003   1970       1     0  ...     -9.0     -9.0       1.0     1.0
#
# [5 rows x 133 columns]

# %% [markdown]
# Analysing Target Type Of Attack vs Target Subtype On People

# %%
fig=plt.figure(figsize=(15,7))
sns.stripplot(x=df["targtype1"],y=df["targsubtype1"],color="lime")
